# %% [markdown]
# # Primera entrega ML

# %% [markdown]
# ### Título de proyecto

# %%
# Escribir el título de proyecto en Markdown
titulo = "Tennis Predict"

# %% [markdown]
# ### Tema

# %%
tema = "Predicción de estadísticas sobre partidos de tenis" # Breve descripción del proyecto

# %%
# Describir el tema en Markdown

# %% [markdown]
# ### Datasets y fuentes alternativas de datos
# Incluye aquí una breve descripción del dataset o datasets para tu proyecto. Incluye también las fuentes de cada uno de ellos.

# %%
tipo_ml = "Regresión" # Regresión? Clasificación?
target_descr = "minutes, que representa el tiempo que va a durar un partido en minutos" # Descripción de la variable objetivo
metricas = ["accuracy"] # Metricas escogidas para evaluar los modelos

# %%
# dasets y enlaces de datasets en Markdown
enlaces = ["https://www.kaggle.com/datasets/warcoder/atp-tennis-rankings-results-and-stats1968-2023"] # ["www.paginacondatos.com", "www.paginawebscrapeada.com", "www.unaapi.com"]

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.read_csv("atp_matches_2023.csv", sep=";")
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2023-9900   United Cup    Hard         18             A      20230102
# 1  2023-9900   United Cup    Hard         18             A      20230102
# 2  2023-9900   United Cup    Hard         18             A      20230102
# 3  2023-9900   United Cup    Hard         18             A      20230102
# 4  2023-9900   United Cup    Hard         18             A      20230102
#
#    match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0        300     126203          3.0          NaN        Taylor Fritz
# 1        299     126207          NaN          NaN      Frances Tiafoe
# 2        296     126203          3.0          NaN        Taylor Fritz
# 3        295     126207          NaN          NaN      Frances Tiafoe
# 4        292     126774          1.0          NaN  Stefanos Tsitsipas
#
#   winner_hand  winner_ht winner_ioc  winner_age  loser_id  loser_seed  \
# ...
